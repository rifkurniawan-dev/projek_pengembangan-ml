# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.11/dist-packages (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.10.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (1.15.2)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (3.6.0)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report
from imblearn.over_sampling import SMOTE

# %%
df = pd.read_csv('tokopedia_prosesss.csv')

# %%
df
# Out:
#       Unnamed: 0                                            content  score  \
# 0              0  Aneh sekali pihak tokopedia, bukannya diperbai...      1
# 1              1  Kolaborasi & integrasi Tokopedia, Gopay dan Ba...      1
# 2              2  semakin di update UI/UXnya malah bikin bingung...      1
# 3              3  Masukan untuk team Developer-nya. Tolong dilak...      1
# 4              4  tokopedia memang buruk !!! saya belanja order ...      1
# ...          ...                                                ...    ...
# 7080        9994  Banyak aplikasi belanja cuma satu yg paling gw...      2
# 7081        9996  Makin kesini ini app makin lemot aja, gk kaya ...      1
# 7082        9997  Sdh bertahun2 pakai, Selalu jadi andalan kalo ...      1
# 7083        9998  Kl tersedia voucher diskon atau lainnya harusn...      2
# 7084        9999  Baru pesan barang setelah pembayaran langsung ...      1
#
#                                              text_clean  \
# 0     Aneh sekali pihak tokopedia bukannya diperbaik...
# 1     Kolaborasi  integrasi Tokopedia Gopay dan Bank...
# 2     semakin di update UIUXnya malah bikin bingung ...
# 3     Masukan untuk team Developernya Tolong dilakuk...
# 4     tokopedia memang buruk  saya belanja order sud...
# ...                                                 ...
# 7080  Banyak aplikasi belanja cuma satu yg paling gw...
# 7081  Makin kesini ini app makin lemot aja gk kaya s...
# 7082  Sdh bertahun2 pakai Selalu jadi andalan kalo b...
# 7083  Kl tersedia voucher diskon atau lainnya harusn...
# 7084  Baru pesan barang setelah pembayaran langsung ...
#
#                                     text_tokenizingText  \
# 0     ['Aneh', 'sekali', 'pihak', 'tokopedia', 'buka...
# 1     ['Kolaborasi', 'integrasi', 'Tokopedia', 'Gopa...
# 2     ['semakin', 'di', 'update', 'UIUXnya', 'malah'...
# 3     ['Masukan', 'untuk', 'team', 'Developernya', '...
# 4     ['tokopedia', 'memang', 'buruk', 'saya', 'bela...
# ...                                                 ...
# 7080  ['Banyak', 'aplikasi', 'belanja', 'cuma', 'sat...
# 7081  ['Makin', 'kesini', 'ini', 'app', 'makin', 'le...
# 7082  ['Sdh', 'bertahun2', 'pakai', 'Selalu', 'jadi'...
# 7083  ['Kl', 'tersedia', 'voucher', 'diskon', 'atau'...
# 7084  ['Baru', 'pesan', 'barang', 'setelah', 'pembay...
#
#                                           text_stopword  \
# 0     ['Aneh', 'tokopedia', 'diperbaiki', 'aplikasi'...
# 1     ['Kolaborasi', 'integrasi', 'Tokopedia', 'Gopa...
# 2     ['update', 'UIUXnya', 'bikin', 'bingung', 'not...
# 3     ['Masukan', 'team', 'Developernya', 'Tolong', ...
# 4     ['tokopedia', 'buruk', 'belanja', 'order', '3'...
# ...                                                 ...
# 7080  ['Banyak', 'aplikasi', 'belanja', 'yg', 'gw', ...
# 7081  ['Makin', 'kesini', 'app', 'lemot', 'aja', 'gk...
# 7082  ['Sdh', 'bertahun2', 'pakai', 'Selalu', 'andal...
# 7083  ['Kl', 'tersedia', 'voucher', 'diskon', 'dipil...
# 7084  ['Baru', 'pesan', 'barang', 'pembayaran', 'lan...
#
#                                           content_clean  \
# 0     Aneh tokopedia diperbaiki aplikasi tiktok Dan ...
# 1     Kolaborasi integrasi Tokopedia Gopay Bank Jago...
# 2     update UIUXnya bikin bingung notifikasi cek pe...
# 3     Masukan team Developernya Tolong optimasi apli...
# 4     tokopedia buruk belanja order 3 harisama penju...
# ...                                                 ...
# 7080  Banyak aplikasi belanja yg gw suka Tokopedia t...
# 7081  Makin kesini app lemot aja gk kaya Ditambah ek...
# 7082  Sdh bertahun2 pakai Selalu andalan kalo belanj...
# 7083  Kl tersedia voucher diskon dipilih voucher ses...
# 7084  Baru pesan barang pembayaran langsung batalkan...
#
#                                            stemmingText score_label     label
# 0     aneh tokopedia diperbaiki aplikasi tiktok dan ...    Negative   neutral
# 1     kolaborasi integrasi tokopedia gopay bank jago...    Negative  Positive
# 2     updat uiuxnya bikin bingung notifikasi cek pes...    Negative  negative
# 3     masukan team developernya tolong optimasi apli...    Negative  Positive
# 4     tokopedia buruk belanja order 3 harisama penju...    Negative  negative
# ...                                                 ...         ...       ...
# 7080  banyak aplikasi belanja yg gw suka tokopedia t...    Negative  Positive
# 7081  makin kesini app lemot aja gk kaya ditambah ek...    Negative  negative
# 7082  sdh bertahun2 pakai selalu andalan kalo belanj...    Negative  negative
# 7083  kl tersedia voucher diskon dipilih voucher ses...    Negative  negative
# 7084  baru pesan barang pembayaran langsung batalkan...    Negative  Positive
#
# [7085 rows x 10 columns]

# %%
X = df['stemmingText'].astype(str)
y = df['label']

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
tfidf = TfidfVectorizer(max_features=5000)
X_tfidf = tfidf.fit_transform(X)

# %%
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_tfidf, y_encoded)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled, test_size=0.2, random_state=42
)

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Random Forest": RandomForestClassifier(),
    "SVM": SVC(),
    "Multinomial Naive Bayes": MultinomialNB()
}

for name, model in models.items():
    print(f"Model: {name}")
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    print(f"Akurasi: {acc*100:.2f}%")
    print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))
    print("-" * 60)
# Out:
# Model: Logistic Regression
# Akurasi: 83.10%
#               precision    recall  f1-score   support
#
#     Positive       0.93      0.79      0.85       691
#     negative       0.82      0.78      0.80       740
#      neutral       0.77      0.92      0.84       699
#
#     accuracy                           0.83      2130
#    macro avg       0.84      0.83      0.83      2130
# weighted avg       0.84      0.83      0.83      2130
#
# ------------------------------------------------------------
# Model: Random Forest
# Akurasi: 88.40%
#               precision    recall  f1-score   support
#
#     Positive       0.95      0.86      0.90       691
#     negative       0.85      0.85      0.85       740
#      neutral       0.86      0.95      0.90       699
#
#     accuracy                           0.88      2130
#    macro avg       0.89      0.88      0.88      2130
# weighted avg       0.89      0.88      0.88      2130
#
# ------------------------------------------------------------
# Model: SVM
# Akurasi: 87.56%
#               precision    recall  f1-score   support
#
#     Positive       0.97      0.80      0.88       691
#     negative       0.75      0.98      0.85       740
#      neutral       0.98      0.85      0.91       699
#
#     accuracy                           0.88      2130
#    macro avg       0.90      0.87      0.88      2130
# weighted avg       0.90      0.88      0.88      2130
#
# ------------------------------------------------------------
# Model: Multinomial Naive Bayes
# Akurasi: 77.14%
#               precision    recall  f1-score   support
#
#     Positive       0.78      0.77      0.78       691
#     negative       0.74      0.69      0.72       740
#      neutral       0.79      0.85      0.82       699
#
#     accuracy                           0.77      2130
#    macro avg       0.77      0.77      0.77      2130
# weighted avg       0.77      0.77      0.77      2130
#
# ------------------------------------------------------------
